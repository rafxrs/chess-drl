# %% [markdown]
# # Chess DRL Pipeline

# %% [markdown]
# ## 1. Setup

# %%
# Mount Google Drive to save models between sessions
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone from GitHub
# !git clone https://rafxrs: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@github.com/rafxrs/chess-drl.git
# %cd chess-drl
# Out:
# Cloning into 'chess-drl'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 135 (delta 6), reused 12 (delta 5), pack-reused 116 (from 1)
# Receiving objects: 100% (135/135), 161.30 MiB | 16.67 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# /content/chess-drl

# %%
# Install dependencies
# !pip install -r "code/requirements.txt"
# Out:
# Collecting python-chess>=1.9.4 (from -r code/requirements.txt (line 2))
#   Downloading python_chess-1.999-py3-none-any.whl.metadata (776 bytes)
# Requirement already satisfied: numpy>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 3)) (2.0.2)
# Requirement already satisfied: torch>=2.0.1 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 4)) (2.6.0+cu124)
# Collecting python-dotenv>=1.0.0 (from -r code/requirements.txt (line 5))
#   Downloading python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 6)) (4.67.1)
# Requirement already satisfied: pygame>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 9)) (2.6.1)
# Collecting pygame-popup>=0.9.1 (from -r code/requirements.txt (line 10))
#   Downloading pygame_popup-0.10.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: setproctitle>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 13)) (1.3.6)
# Requirement already satisfied: matplotlib>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 14)) (3.10.0)
# Requirement already satisfied: tensorboard>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 17)) (2.18.0)
# Requirement already satisfied: psutil>=5.9.5 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 18)) (5.9.5)
# Requirement already satisfied: pytest>=7.3.1 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 21)) (8.3.5)
# Collecting black>=23.3.0 (from -r code/requirements.txt (line 22))
#   Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.3 MB/s eta 0:00:00
# Collecting pylint>=2.17.4 (from -r code/requirements.txt (line 23))
#   Downloading pylint-3.3.7-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: pynvml>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from -r code/requirements.txt (line 24)) (12.0.0)
# Collecting chess<2,>=1 (from python-chess>=1.9.4->-r code/requirements.txt (line 2))
#   Downloading chess-1.11.2.tar.gz (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 110.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.1->-r code/requirements.txt (line 4))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.1->-r code/requirements.txt (line 4)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.1->-r code/requirements.txt (line 4)) (1.3.0)
# Collecting pygame-ce>=2.0.0 (from pygame-popup>=0.9.1->-r code/requirements.txt (line 10))
#   Downloading pygame_ce-2.5.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.7.1->-r code/requirements.txt (line 14)) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (3.8)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (3.1.3)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.11/dist-packages (from pytest>=7.3.1->-r code/requirements.txt (line 21)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=7.3.1->-r code/requirements.txt (line 21)) (1.6.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black>=23.3.0->-r code/requirements.txt (line 22)) (8.2.1)
# Collecting mypy-extensions>=0.4.3 (from black>=23.3.0->-r code/requirements.txt (line 22))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black>=23.3.0->-r code/requirements.txt (line 22))
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black>=23.3.0->-r code/requirements.txt (line 22)) (4.3.8)
# Collecting astroid<=3.4.0.dev0,>=3.3.8 (from pylint>=2.17.4->-r code/requirements.txt (line 23))
#   Downloading astroid-3.3.10-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: dill>=0.3.6 in /usr/local/lib/python3.11/dist-packages (from pylint>=2.17.4->-r code/requirements.txt (line 23)) (0.3.7)
# Collecting isort!=5.13,<7,>=4.2.5 (from pylint>=2.17.4->-r code/requirements.txt (line 23))
#   Downloading isort-6.0.1-py3-none-any.whl.metadata (11 kB)
# Collecting mccabe<0.8,>=0.6 (from pylint>=2.17.4->-r code/requirements.txt (line 23))
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from pylint>=2.17.4->-r code/requirements.txt (line 23)) (0.13.2)
# Requirement already satisfied: nvidia-ml-py<13.0.0a0,>=12.0.0 in /usr/local/lib/python3.11/dist-packages (from pynvml>=12.0.0->-r code/requirements.txt (line 24)) (12.575.51)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.13.0->-r code/requirements.txt (line 17)) (3.0.2)
# Downloading python_chess-1.999-py3-none-any.whl (1.4 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 129.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 103.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 44.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 20.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.7 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading pygame_popup-0.10.0-py3-none-any.whl (35 kB)
# Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 81.4 MB/s eta 0:00:00
# Downloading pylint-3.3.7-py3-none-any.whl (522 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 522.6/522.6 kB 42.7 MB/s eta 0:00:00
# Downloading astroid-3.3.10-py3-none-any.whl (275 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 275.4/275.4 kB 27.1 MB/s eta 0:00:00
# Downloading isort-6.0.1-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.2/94.2 kB 9.5 MB/s eta 0:00:00
# Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pygame_ce-2.5.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.5/12.5 MB 18.1 MB/s eta 0:00:00
# Building wheels for collected packages: chess
#   Building wheel for chess (setup.py) ... done
#   Created wheel for chess: filename=chess-1.11.2-py3-none-any.whl size=147775 sha256=d233947de2b2956fd95f39b61d3fb3f6d7ed76af356fa28f1fa0adfd1e6b4248
#   Stored in directory: /root/.cache/pip/wheels/fb/5d/5c/59a62d8a695285e59ec9c1f66add6f8a9ac4152499a2be0113
# Successfully built chess
# Installing collected packages: python-dotenv, pygame-ce, pathspec, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, mccabe, isort, chess, astroid, python-chess, pylint, pygame-popup, nvidia-cusparse-cu12, nvidia-cudnn-cu12, black, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed astroid-3.3.10 black-25.1.0 chess-1.11.2 isort-6.0.1 mccabe-0.7.0 mypy-extensions-1.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pathspec-0.12.1 pygame-ce-2.5.4 pygame-popup-0.10.0 pylint-3.3.7 python-chess-1.999 python-dotenv-1.1.0

# %%
# Check GPU
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# CUDA available: True
# GPU: NVIDIA L4

# %% [markdown]
# ## 2. Training

# %%
# Optional: Generate initial data
# !python code/generate_data.py --model models/model_latest.pt --games 100 --output memory/selfplay_data.npz --gpu
# Out:
#  Using GPU: NVIDIA L4
#  Generating 100 self-play games using model models/model_latest.pt
#  Using GPU (NVIDIA L4) for model initialization
# Self-play games:   0% 0/100 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/chess-drl/code/generate_data.py", line 267, in <module>
#     main()
#   File "/content/chess-drl/code/generate_data.py", line 259, in main
#     generate_selfplay_data_parallel(args.model, args.games, args.output, device)
#   File "/content/chess-drl/code/generate_data.py", line 150, in generate_selfplay_data_parallel
#     results = list(tqdm(pool.imap(lambda x: game_fn(game_id=x), range(n_games)),
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/tqdm/std.py", line 1181, in __iter__
#     for obj in iterable:
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 873, in next
#     raise value
#   File "/usr/lib/python3.11/multiprocessing/pool.py", line 540, in _handle_tasks
#     put(task)
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 206, in send
#     self._send_bytes(_ForkingPickler.dumps(obj))
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/reduction.py", line 51, in dumps
#     cls(buf, protocol).dump(obj)
# AttributeError: Can't pickle local object 'generate_selfplay_data_parallel.<locals>.<lambda>'

# %%
# Run training
# !python code/train.py --model models/initial_model.pt --data memory/colab_data.npz --epochs 20

# Show the training loss plot
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from glob import glob
latest_plot = sorted(glob('plots/*.png'))[-1]
img = mpimg.imread(latest_plot)
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis('off')
plt.show()

# Download trained model
from google.colab import files
files.download('models/model_final.pt')
# Out:
#  NumExpr defaulting to 12 threads.
#  Using device: cuda
# Traceback (most recent call last):
#   File "/content/chess-drl/code/train.py", line 538, in <module>
#     main()
#   File "/content/chess-drl/code/train.py", line 480, in main
#     raise ValueError("Not enough training data and --generate not specified")
# ValueError: Not enough training data and --generate not specified
# ---------------------------------------------------------------------------
#
# IndexError                                Traceback (most recent call last)
#
# <ipython-input-13-065963537c05> in <cell line: 0>()
#
#       6 import matplotlib.image as mpimg
#
#       7 from glob import glob
#
# ----> 8 latest_plot = sorted(glob('plots/*.png'))[-1]
#
#       9 img = mpimg.imread(latest_plot)
#
#      10 plt.figure(figsize=(12, 8))
#
#
#
# IndexError: list index out of range
